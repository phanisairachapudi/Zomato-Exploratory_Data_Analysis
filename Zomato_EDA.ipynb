# %% [markdown]
# # Zomato Dataset Exploratory Data Analysis

# %%
# import required libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Get the zomato dataset

df_zomato = pd.read_csv('zomato.csv', encoding = 'latin-1')

# %%
# view first 5 records

df_zomato.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# view what are all columns are there in dataset

df_zomato.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
# view more information about the spam data using describe method

df_zomato.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
# view what are all columns are null and datatypes of columns.
df_zomato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
# check there are any null values present

df_zomato.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# Based on above information. Cuisines has 9 missing values

# %% [markdown]
# Now combine our zomato dataset with country-code dataset. We're doing because we've country code in zomato dataset. But, it was missing country name.

# %%
# Get the country-code dataset

df_country = pd.read_excel('country-code.xlsx')

# %%
# view first 5 records

df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
# view any null values are there

df_country.isnull().sum()
# Out:
# Country Code    0
# Country         0
# dtype: int64

# %% [markdown]
# Using country code column in zomato and country datasets. we are comibing these two datasets using pandas merge method.

# %%
df_final = pd.merge(df_zomato, df_country, on = 'Country Code', how = 'left')

# %%
# view first 5 records

df_final.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# view what are all columns are there in dataset after merged

df_final.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
# check how many records based on countries

df_final.Country.value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %% [markdown]
# Plotting a graph for showing which top 3 countries uses zomato most

# %%
country_names = df_final.Country.value_counts().index

# %%
country_values = df_final.Country.value_counts().values

# %%
# Pie Charts

plt.pie(country_values[:3], labels = country_names[:3], autopct = '%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x19e50446f40>,
# ...
#  [Text(-1.0829742700952103, 0.19278674827836725, 'India'),
#   Text(1.077281715838356, -0.22240527134123297, 'United States'),
#   Text(1.0995865153823035, -0.03015783794312073, 'United Kingdom')],
#  [Text(-0.590713238233751, 0.10515640815183668, '94.39%'),
#   Text(0.5876082086391032, -0.12131196618612707, '4.73%'),
#   Text(0.5997744629358018, -0.01644972978715676, '0.87%')])

# %% [markdown]
# Zomato has maximum transactions are from India with 94.39%.
# United States is 4.73%.
# United Kingdom is 0.87%.

# %%
# view first 5 records

df_final.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# Using final dataset find out best restaurants based on Aggregate Ratings

# %%
df_best = df_final.sort_values(by='Aggregate rating', ascending = False).copy()

df_best.loc[:,["Restaurant Name", "City", "Address", "Cuisines", "Votes", "Aggregate rating"]]
# Out:
#                     Restaurant Name       City  \
# 1381                    Caterspoint    Gurgaon
# 589         AB's Absolute Barbecues      Dubai
# 374   McGuire's Irish Pub & Brewery  Pensacola
# 9303                          Miann   Auckland
# 9299                          Milse   Auckland
# ...                             ...        ...
# 4034        Mirch Masala Restaurant  New Delhi
# 4033          Kashmiri Hills Wazwan  New Delhi
# 4029            New Classic Kitchen  New Delhi
# 4025     Frugurpop-  ibis New Delhi  New Delhi
# 5426             Swadist Bhojnalaya  New Delhi
#
#                                                 Address  \
# 1381                      S-27/11, DLF Phase 3, Gurgaon
# 589   Mezzanaine Floor, Centurion Star Tower, Deira ...
# 374           600 E Gregory Street, Pensacola, FL 32502
# 9303              57 Fort Street, Auckland Auckland CBD
# 9299  The Pavilions, 27 Tyler Street, Britomart, Auc...
# ...

# %% [markdown]
# Top 10 resturants based on ratings

# %%
def_best_10 = df_best.loc[:,["Restaurant Name", "City", "Address", "Cuisines", "Votes", "Aggregate rating"]].head(10)

def_best_10
# Out:
#                     Restaurant Name            City  \
# 1381                    Caterspoint         Gurgaon
# 589         AB's Absolute Barbecues           Dubai
# 374   McGuire's Irish Pub & Brewery       Pensacola
# 9303                          Miann        Auckland
# 9299                          Milse        Auckland
# 9296               Talaga Sampireun       Tangerang
# 50                Garota de Ipanema  Rio de Janeiro
# 9291               Talaga Sampireun         Jakarta
# 48               Braseiro da Gíçvea  Rio de Janeiro
# 428               Mama's Fish House  Rest of Hawaii
#
#                                                 Address  \
# 1381                      S-27/11, DLF Phase 3, Gurgaon
# 589   Mezzanaine Floor, Centurion Star Tower, Deira ...
# 374           600 E Gregory Street, Pensacola, FL 32502
# 9303              57 Fort Street, Auckland Auckland CBD
# 9299  The Pavilions, 27 Tyler Street, Britomart, Auc...
# ...

# %% [markdown]
# Let's find out best dishes(Cuisines) based on votes

# %% [markdown]
# Let's take one city to find details about that city. For example: Noida

# %%
df_final.City.value_counts().head(20)
# Out:
# New Delhi         5473
# Gurgaon           1118
# Noida             1080
# Faridabad          251
# Ghaziabad           25
# Bhubaneshwar        21
# Amritsar            21
# Ahmedabad           21
# Lucknow             21
# Guwahati            21
# Ludhiana            20
# Rest of Hawaii      20
# Kochi               20
# Kolkata             20
# Pocatello           20
# Pensacola           20
# Mumbai              20
# Mangalore           20
# Singapore           20
# Orlando             20
# Name: City, dtype: int64

# %%
df_city = df_final[(df_final.City == 'New Delhi')]

# %%
df_city.head(10)
# Out:
#       Restaurant ID  Restaurant Name  Country Code       City  \
# 2560       18287358       Food Cloud             1  New Delhi
# 2561       18216944        Burger.in             1  New Delhi
# 2562         313333  Days of the Raj             1  New Delhi
# 2563       18384127   Dilli Ka Dhaba             1  New Delhi
# 2564            582        Govardhan             1  New Delhi
# 2565       18414465   Mezbaan Grills             1  New Delhi
# 2566         304243       Say Cheese             1  New Delhi
# 2567           3554           Southy             1  New Delhi
# 2568       18369872          Monosoz             1  New Delhi
# 2569            948            Waves             1  New Delhi
#
#                                                 Address    Locality  \
# 2560                              Aaya Nagar, New Delhi  Aaya Nagar
# 2561        84, Near Honda Showroom, Adchini, New Delhi     Adchini
# 2562  81/3, 1st Floor, Qutub Residency, Adchini, New...     Adchini
# ...

# %%
# Find most preferred dishes or top 10 dishes in noida

plt.figure(figsize = (20,10))
sns.barplot(y = df_city.Cuisines.value_counts()[:10,].index, x = df_city.Cuisines.value_counts()[:10,], data = df_city)
# Out:
# <AxesSubplot:xlabel='Cuisines'>

# %% [markdown]
# In New Delhi city, most people eat North Indian, Chinese, Fast Food

# %% [markdown]
# ## Let's take area from New Delhi city and
#
# 1. Find out Which dish people like most
# 2. Find top 5 resturants for most like dish in that area

# %%
df_city.head()
# Out:
#       Restaurant ID  Restaurant Name  Country Code       City  \
# 2560       18287358       Food Cloud             1  New Delhi
# 2561       18216944        Burger.in             1  New Delhi
# 2562         313333  Days of the Raj             1  New Delhi
# 2563       18384127   Dilli Ka Dhaba             1  New Delhi
# 2564            582        Govardhan             1  New Delhi
#
#                                                 Address    Locality  \
# 2560                              Aaya Nagar, New Delhi  Aaya Nagar
# 2561        84, Near Honda Showroom, Adchini, New Delhi     Adchini
# 2562  81/3, 1st Floor, Qutub Residency, Adchini, New...     Adchini
# 2563  66 A, Ground Floor, Sri Aurobindo Marg, Adchin...     Adchini
# 2564  84, Adjacent Hero Motor Bike Showroom, Main Me...     Adchini
#
#            Locality Verbose  Longitude   Latitude  \
# 2560  Aaya Nagar, New Delhi   0.000000   0.000000
# 2561     Adchini, New Delhi  77.196923  28.535382
# ...

# %%
df_city.Locality.value_counts()
# Out:
# Connaught Place                 122
# Rajouri Garden                   99
# Shahdara                         87
# Defence Colony                   86
# Pitampura                        85
#                                ...
# Dr. Zakir Hussain Marg            1
# Lemon Tree Premier, Aerocity      1
# Tilak Marg                        1
# Trilokpuri                        1
# Aaya Nagar                        1
# Name: Locality, Length: 254, dtype: int64

# %% [markdown]
# Let's take area as Defence Colony for analysis

# %%
df_area = df_city[df_city.Locality == 'Defence Colony']

df_area.head()
# Out:
#       Restaurant ID                            Restaurant Name  Country Code  \
# 3184            763                                   Aka Saka             1
# 3185           7557                          Anil Mishtan Wala             1
# 3186            525                                    Barista             1
# 3187           7561                           Cafe 1 Fast Food             1
# 3188       18387105  Cake Central - Premier Cake Design Studio             1
#
#            City                                            Address  \
# 3184  New Delhi         28, Main Market, Defence Colony, New Delhi
# 3185  New Delhi  23-24, Defence Colony Market, Defence Colony, ...
# 3186  New Delhi  15, Gyandeep, Main Market, Defence Colony, New...
# 3187  New Delhi                     A-1, Defence Colony, New Delhi
# 3188  New Delhi                D  Block, Defence Colony, New Delhi
#
#             Locality           Locality Verbose  Longitude   Latitude  \
# ...

# %% [markdown]
# Let's check rating for dishes given by people

# %%
# find top dishes in area based on ratings

plt.figure(figsize = (10, 19))
sns.barplot(data = df_area, y = 'Cuisines', x = 'Aggregate rating')
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Cuisines'>

# %% [markdown]
# Most people liked Italian, French.

# %%
df_area.rename(columns = {'Restaurant Name':'Restaurant_Name'}, inplace = True)
df_area.head()
# Out:
# C:\Users\Phani Sai\AppData\Local\Temp\ipykernel_5832\1964190521.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_area.rename(columns = {'Restaurant Name':'Restaurant_Name'}, inplace = True)
#       Restaurant ID                            Restaurant_Name  Country Code  \
# 3184            763                                   Aka Saka             1
# 3185           7557                          Anil Mishtan Wala             1
# 3186            525                                    Barista             1
# 3187           7561                           Cafe 1 Fast Food             1
# 3188       18387105  Cake Central - Premier Cake Design Studio             1
#
#            City                                            Address  \
# ...

# %%
# find top 5 or 10 restaurants in that area by votes

plt.figure(figsize = (12, 16))
sns.barplot(x = 'Votes', y = 'Restaurant_Name', data = df_area)
# Out:
# <AxesSubplot:xlabel='Votes', ylabel='Restaurant_Name'>

# %% [markdown]
# RoadRomeo, Hong Kong Express, Def Col Social, Kent's Fast Food, Swagath are best resturants preferred by people

# %% [markdown]
# Let's check which restuarants more ratings

# %%
plt.figure(figsize = (12, 18))

sns.barplot(x = 'Aggregate rating', y = 'Restaurant_Name', data = df_area)
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Restaurant_Name'>

# %% [markdown]
# Bonne Bouche, Zaakia Junction, The Culinary Pitaara, Whipped restaurants has more ratings

# %% [markdown]
# # Lets's check how many restaurants has online delivery and table booking

# %%
df_area.head()
# Out:
#       Restaurant ID                            Restaurant_Name  Country Code  \
# 3184            763                                   Aka Saka             1
# 3185           7557                          Anil Mishtan Wala             1
# 3186            525                                    Barista             1
# 3187           7561                           Cafe 1 Fast Food             1
# 3188       18387105  Cake Central - Premier Cake Design Studio             1
#
#            City                                            Address  \
# 3184  New Delhi         28, Main Market, Defence Colony, New Delhi
# 3185  New Delhi  23-24, Defence Colony Market, Defence Colony, ...
# 3186  New Delhi  15, Gyandeep, Main Market, Defence Colony, New...
# 3187  New Delhi                     A-1, Defence Colony, New Delhi
# 3188  New Delhi                D  Block, Defence Colony, New Delhi
#
#             Locality           Locality Verbose  Longitude   Latitude  \
# ...

# %%
df_area.shape
# Out:
# (86, 22)

# %%
# checking online delivery

sns.countplot(x = 'Has Online delivery', data = df_area)
# Out:
# <AxesSubplot:xlabel='Has Online delivery', ylabel='count'>

# %% [markdown]
# Out of 86 restaurants more than half has online delivery facility

# %%
# checking table booking for restaurants

sns.countplot(x = 'Has Table booking', data = df_area)
# Out:
# <AxesSubplot:xlabel='Has Table booking', ylabel='count'>
